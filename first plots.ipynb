# %%
import geopandas as gpd
import matplotlib as plt

gdf_5 = gpd.read_file('data-3D-house/shapefiles_K_5/DHMVII_vdc_k5.shp')
print (gdf_5)
# Out:
#         Date   OpnDatum1   OpnDatum2  \
# 0   20140319  2014-03-19        None
# 1   20140317  2014-03-19  2014-03-17
# 2   20140317  2014-03-17        None
# 3   20140317  2014-03-17  2014-03-30
# 4   20140330  2014-03-30        None
# 5   20140330  2014-03-30  2014-03-31
# 6   20140331  2014-03-31        None
# 7   20140331  2014-03-31  2014-04-01
# 8   20140401  2014-04-01        None
# 9   20140401  2014-04-01  2014-04-02
# 10  20140402  2014-04-02        None
#
#                                              geometry
# 0   POLYGON Z ((86000.000 230206.366 0.000, 85998....
# 1   POLYGON Z ((86000.000 230206.366 0.000, 86000....
# 2   MULTIPOLYGON Z (((97000.000 228000.000 0.000, ...
# 3   MULTIPOLYGON Z (((95075.940 227675.980 0.000, ...
# 4   POLYGON Z ((87000.000 227360.941 0.000, 87000....
# 5   MULTIPOLYGON Z (((67106.560 224569.260 0.000, ...
# 6   POLYGON Z ((98000.000 224213.494 0.000, 98000....
# 7   MULTIPOLYGON Z (((66364.220 220127.500 0.000, ...
# ...

# %%
# %matplotlib inline
gdf_5.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_12 = gpd.read_file('data-3D-house/shapefiles_K_12/DHMVII_vdc_k12.shp')
print (gdf_12)
# Out:
#         Date  Id     area   OpnDatum1   OpnDatum2 OpnDatum3  \
# 0   20140409   0  52900.0  2014-04-09        None      None
# 1   20140410   0  52900.0  2014-04-10        None      None
# 2   20140411   0  52900.0  2014-04-11        None      None
# 3   20140412   0  52900.0  2014-04-12        None      None
# 4   20140413   0  52900.0  2014-04-13        None      None
# 5   20140414   0  52900.0  2014-04-14        None      None
# 6   20140409   0  52900.0  2014-04-09  2014-04-10      None
# 7   20140412   0  52900.0  2014-04-10  2014-04-12      None
# 8   20140411   0  52900.0  2014-04-11  2014-04-12      None
# 9   20140413   0  52900.0  2014-04-12  2014-04-13      None
# 10  20140413   0  52900.0  2014-04-13  2014-04-14      None
# 11  20140411   0  52900.0  2014-04-11  2014-04-12      None
#
#                                              geometry
# 0   POLYGON Z ((66000.000 216680.142 0.000, 65991....
# 1   POLYGON Z ((66000.000 216333.399 0.000, 66000....
# ...

# %%
gdf_12.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_13 = gpd.read_file('data-3D-house/shapefiles_K_13/DHMVII_vdc_k13.shp')
print (gdf_13)
# Out:
#         Date   OpnDatum1   OpnDatum2  \
# 0   20150305  2015-03-05        None
# 1   20150306  2015-03-06        None
# 2   20150308  2015-03-08        None
# 3   20150310  2015-03-10        None
# 4   20150311  2015-03-11        None
# 5   20150312  2015-03-12        None
# 6   20150306  2015-03-05  2015-03-06
# 7   20150308  2015-03-06  2015-03-08
# 8   20150308  2015-03-08  2015-03-10
# 9   20150311  2015-03-10  2015-03-11
# 10  20150312  2015-03-11  2015-03-12
# 11  20150313  2015-03-12  2015-03-13
#
#                                              geometry
# 0   POLYGON Z ((98000.000 217783.121 0.000, 97997....
# 1   POLYGON Z ((98000.000 217465.109 0.000, 98000....
# 2   POLYGON Z ((98000.000 213046.450 0.000, 98000....
# 3   POLYGON Z ((98000.000 209075.241 0.000, 98000....
# 4   POLYGON Z ((98000.000 204542.782 0.000, 98000....
# 5   POLYGON Z ((98000.000 200890.510 0.000, 98000....
# 6   POLYGON Z ((98000.000 217783.121 0.000, 98000....
# ...

# %%
gdf_13.plot()
# Out:
# <AxesSubplot:>

# %%
gdf1 = gpd.read_file('data-3D-house/versnijdingen_shapes/Kbl.shp')
gdf1.plot()
print(gdf1)
# Out:
#     UIDN  OIDN CODE               NAAM       OPPERVL    LENGTE  \
# 0      1     1    1              Essen  6.400000e+08  104000.0
# 1      2     2    2             Meerle  6.400000e+08  104000.0
# 2      3     3    3             Maarle  6.400000e+08  104000.0
# 3      4     4    6         Watervliet  6.400000e+08  104000.0
# 4      5     5    8           Turnhout  6.400000e+08  104000.0
# 5      6     6    4       Blankenberge  6.400000e+08  104000.0
# 6      7     7    5        Westkapelle  6.400000e+08  104000.0
# 7      8     8   10          Beverbeek  6.400000e+08  104000.0
# 8      9     9    7           Kapellen  6.400000e+08  104000.0
# 9     10    10    9           Arendonk  6.400000e+08  104000.0
# 10    11    11   12           Oostende  6.400000e+08  104000.0
# 11    12    12   16               Lier  6.400000e+08  104000.0
# 12    13    13   18            Maaseik  6.400000e+08  104000.0
# 13    14    14   15          Antwerpen  6.400000e+08  104000.0
# ...
